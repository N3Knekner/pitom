# %%
import pandas as pd
import sqlite3 as sql

# %%
conexao_normalizada = sql.connect('globalstore_normalizada.db')

# %%
with conexao_normalizada:
    products = pd.read_sql(
        con = conexao_normalizada, 
        sql="select * from products"
    )

# %%
products
# Out:
#        index  pro_sequence        product_id  \
# 0          0             0   OFF-LA-10002782
# 1          1             1   FUR-FU-10004015
# 2          2             2   FUR-BO-10002352
# 3          3             3   OFF-BI-10004428
# 4          4             4   OFF-AR-10004594
# ...      ...           ...               ...
# 10763  10763         50913  FUR-DAN-10001557
# 10764  10764         50924  OFF-KRA-10002441
# 10765  10765         51075  OFF-GRE-10003213
# 10766  10766         51155  FUR-CHR-10000888
# 10767  10767         51185  OFF-OIC-10004622
#
#                                      product_name  sub_sequence
# 0              Hon File Folder Labels, Adjustable             0
# 1                            Tenex Clock, Durable             1
# 2                    Ikea 3-Shelf Cabinet, Mobile             2
# 3                          Cardinal Binder, Clear             3
# 4                     Sanford Canvas, Water Color             4
# ...                                           ...           ...
# 10763              Dania Floating Shelf Set, Pine             2
# 10764          Kraft Business Envelopes, Recycled             5
# 10765               Green Bar Memo Slips, Premium            63
# 10766  Chromcraft Computer Table, Fully Assembled            36
# 10767                  OIC Thumb Tacks, Bulk Pack            10
#
# [10768 rows x 5 columns]

# %%
products['product_name_v1'] = products['product_name'].apply(lambda x : x.replace(', ', ' - '))
products
# Out:
#        index  pro_sequence        product_id  \
# 0          0             0   OFF-LA-10002782
# 1          1             1   FUR-FU-10004015
# 2          2             2   FUR-BO-10002352
# 3          3             3   OFF-BI-10004428
# 4          4             4   OFF-AR-10004594
# ...      ...           ...               ...
# 10763  10763         50913  FUR-DAN-10001557
# 10764  10764         50924  OFF-KRA-10002441
# 10765  10765         51075  OFF-GRE-10003213
# 10766  10766         51155  FUR-CHR-10000888
# 10767  10767         51185  OFF-OIC-10004622
#
#                                      product_name  sub_sequence  \
# 0              Hon File Folder Labels, Adjustable             0
# 1                            Tenex Clock, Durable             1
# 2                    Ikea 3-Shelf Cabinet, Mobile             2
# 3                          Cardinal Binder, Clear             3
# 4                     Sanford Canvas, Water Color             4
# ...                                           ...           ...
# 10763              Dania Floating Shelf Set, Pine             2
# 10764          Kraft Business Envelopes, Recycled             5
# 10765               Green Bar Memo Slips, Premium            63
# 10766  Chromcraft Computer Table, Fully Assembled            36
# 10767                  OIC Thumb Tacks, Bulk Pack            10
#
#                                    product_name_v1
# 0              Hon File Folder Labels - Adjustable
# 1                            Tenex Clock - Durable
# 2                    Ikea 3-Shelf Cabinet - Mobile
# 3                          Cardinal Binder - Clear
# 4                     Sanford Canvas - Water Color
# ...                                            ...
# 10763              Dania Floating Shelf Set - Pine
# 10764          Kraft Business Envelopes - Recycled
# 10765               Green Bar Memo Slips - Premium
# 10766  Chromcraft Computer Table - Fully Assembled
# 10767                  OIC Thumb Tacks - Bulk Pack
#
# [10768 rows x 6 columns]

# %%
products['product_name_v2'] = products['product_name_v1'].apply(lambda x : x.split(' - '))
products
# Out:
#        index  pro_sequence        product_id  \
# 0          0             0   OFF-LA-10002782
# 1          1             1   FUR-FU-10004015
# 2          2             2   FUR-BO-10002352
# 3          3             3   OFF-BI-10004428
# 4          4             4   OFF-AR-10004594
# ...      ...           ...               ...
# 10763  10763         50913  FUR-DAN-10001557
# 10764  10764         50924  OFF-KRA-10002441
# 10765  10765         51075  OFF-GRE-10003213
# 10766  10766         51155  FUR-CHR-10000888
# 10767  10767         51185  OFF-OIC-10004622
#
#                                      product_name  sub_sequence  \
# 0              Hon File Folder Labels, Adjustable             0
# 1                            Tenex Clock, Durable             1
# 2                    Ikea 3-Shelf Cabinet, Mobile             2
# 3                          Cardinal Binder, Clear             3
# 4                     Sanford Canvas, Water Color             4
# ...                                           ...           ...
# 10763              Dania Floating Shelf Set, Pine             2
# 10764          Kraft Business Envelopes, Recycled             5
# 10765               Green Bar Memo Slips, Premium            63
# 10766  Chromcraft Computer Table, Fully Assembled            36
# 10767                  OIC Thumb Tacks, Bulk Pack            10
#
#                                    product_name_v1  \
# 0              Hon File Folder Labels - Adjustable
# 1                            Tenex Clock - Durable
# 2                    Ikea 3-Shelf Cabinet - Mobile
# 3                          Cardinal Binder - Clear
# 4                     Sanford Canvas - Water Color
# ...                                            ...
# 10763              Dania Floating Shelf Set - Pine
# 10764          Kraft Business Envelopes - Recycled
# 10765               Green Bar Memo Slips - Premium
# 10766  Chromcraft Computer Table - Fully Assembled
# 10767                  OIC Thumb Tacks - Bulk Pack
#
#                                     product_name_v2
# 0              [Hon File Folder Labels, Adjustable]
# 1                            [Tenex Clock, Durable]
# 2                    [Ikea 3-Shelf Cabinet, Mobile]
# 3                          [Cardinal Binder, Clear]
# 4                     [Sanford Canvas, Water Color]
# ...                                             ...
# 10763              [Dania Floating Shelf Set, Pine]
# 10764          [Kraft Business Envelopes, Recycled]
# 10765               [Green Bar Memo Slips, Premium]
# 10766  [Chromcraft Computer Table, Fully Assembled]
# 10767                  [OIC Thumb Tacks, Bulk Pack]
#
# [10768 rows x 7 columns]

# %%
products['product_name_prepared'] = products.apply(
    lambda x : x['product_id'] + ' - ' + x['product_name_v2'][0] + ' (' + x['product_name_v2'][1] + ')'
        if len(x['product_name_v2']) > 1
        else x['product_id'] + ' - ' + x['product_name_v1'], axis = 1)
products

# %%
import re

# %%
products['numeros'] = products['product_name'].apply(lambda x : re.findall('[0-9]+', x))
products

# %% [markdown]
# ## Discretização de Variáveis

# %%
globalstore = pd.read_csv('globalstore.csv')
globalstore

# %%
globalstore['lucro'] = globalstore['Profit'].apply(lambda x : 1 if x > 0 else 0)

# %%
globalstore['faixa'] = pd.cut(globalstore['Sales'], bins=4)

# %%
globalstore['Order Date'] = globalstore['Order Date'].astype('datetime64[ns]')
globalstore['Ship Date'] = globalstore['Ship Date'].astype('datetime64[ns]')
globalstore['delivery_days'] = (globalstore['Ship Date'] - globalstore['Order Date']).dt.days + 1

# %%
globalstore

# %% [markdown]
# Atividades:
#
# Aplicar a discretização em outras 3 situações na base globalstore.
#
# Aplicar 2 outras situações para tratamento do nome dos produtos na base globalstore.
#
# Normalizar novamente da base com o tratamento de strings e a discritização das variáveis e salvar em banco de dados relacional.
